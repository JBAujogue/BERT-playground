# %% [markdown]
# <div style="font-variant: small-caps;
#       font-weight: normal;
#       font-size: 35px;
#       text-align: center;
#       padding: 15px;
#       margin: 10px;">
#       Dataset processing
#   </div>
#
# <div style="
#       font-weight: normal;
#       font-size: 25px;
#       text-align: center;
#       padding: 15px;
#       margin: 10px;">
#       CHIA
#   </div>
#
#
# <div style="
#       font-weight: normal;
#       font-size: 15px;
#       text-align: center;
#       padding: 15px;
#       margin: 10px;">
#       Jean-baptiste AUJOGUE
#   </div>

# %% [markdown]
# <a id="TOC"></a>

# %% [markdown]
# #### Table Of Content
#
# 1. [CHIA Texts](#texts) <br>
# 2. [CHIA Entities](#ents) <br>
#
#
# #### Useful links
#
# - [CHIA a large annotated corpus of clinical trial eligibility criteria](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7452886/pdf/41597_2020_Article_620.pdf) (paper)
# - https://github.com/uf-hobi-informatics-lab/ClinicalTransformerNER/blob/master/tutorial/brat2bio.ipynb
# - https://github.com/ctgatecci/Clinical-trial-eligibility-criteria-NER/blob/main/NER%20Preprocessing%20and%20Performance%20Analysis.ipynb

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import re
import copy
import json
import zipfile

# data
import pandas as pd

# text
from spacy.lang.en import English

# %% [markdown]
# #### Custom variables

# %%
path_to_repo = os.path.dirname(os.getcwd())
path_to_data = os.path.join(path_to_repo, 'datasets', 'chia')
path_to_src  = os.path.join(path_to_repo, 'src')
path_to_src
# Out:
# 'C:\\Users\\jb\\Desktop\\NLP\\perso - Transformers for NLP\\src'

# %%
base_dataset_name  = 'chia.zip'
final_dataset_name = 'chia-ner'

# %% [markdown]
# #### Custom imports

# %%
sys.path.insert(0, path_to_src)

# %%
from nlptools.dataset.chia.io import load_texts_from_zipfile, load_entities_from_zipfile, dicts_to_jsonl
from nlptools.dataset.chia.preprocessing import get_ner_entities, convert_to_bio, convert_to_prompts

# %% [markdown]
# <a id="texts"></a>

# %% [markdown]
# # 1. CHIA Texts
#
# [Table of content](#TOC)

# %%
folder = os.path.join(path_to_data, final_dataset_name)
if not os.path.isdir(folder):
    os.makedirs(folder)

# %%
df_texts = load_texts_from_zipfile(os.path.join(path_to_data, base_dataset_name))

# %%
df_texts.head()
# Out:
#                 Id                                               Text
# 0  NCT00050349_exc  Patients with symptomatic CNS metastases or le...
# 1  NCT00050349_inc  Patients with biopsy-proven metastatic carcino...
# 2  NCT00061308_exc  Women of child-bearing potential that do not p...
# 3  NCT00061308_inc  Have had one prior platinum-based chemotherapy...
# 4  NCT00094861_exc  Metastatic disease (M1)/stage 4 NSCLC \nPleura...

# %%
df_texts.to_csv(os.path.join(path_to_data, final_dataset_name, 'chia_texts.tsv'), sep = "\t", index = False)

# %% [markdown]
# <a id="ents"></a>

# %% [markdown]
# # 2. CHIA Entities
#
# [Table of content](#TOC)

# %% [markdown]
# ## 2.1 Load entities
#
# [Table of content](#TOC)

# %%
df_ents = load_entities_from_zipfile(os.path.join(path_to_data, base_dataset_name))
df_ents.shape
# Out:
# (44616, 7)

# %%
df_ents.head()
# Out:
#                 Id Entity_id                                   Mention  \
# 0  NCT00050349_exc        T1                            CNS metastases
# 1  NCT00050349_exc        T2                leptomeningeal involvement
# 2  NCT00050349_exc        T5                                   treated
# 3  NCT00050349_exc        T6                           been stable for
# 4  NCT00050349_exc        T7  at least six months prior to study start
#
#     Category  Start_char  End_char  Char_spans
# 0  Condition          26        40    (26, 40)
# 1  Condition          44        70    (44, 70)
# 2  Procedure         144       151  (144, 151)
# 3  Qualifier         164       179  (164, 179)
# 4   Temporal         180       220  (180, 220)

# %%
df_ents[df_ents.Category == 'Qualifier'].Mention.to_list()
# Out:
# ['been stable for',
#  'low dose',
#  'curatively treated',
#  'active',
#  'suspected',
#  'acute',
#  'chronic',
#  'symptomatic',
#  'bone',
#  'stable dose',
#  'clinically stable dose',
#  'previous',
#  'Concomitant',
#  'adequately treated',
#  'has been disease free',
#  'Active uncontrolled',
#  'bone',
#  'severe',
#  'limit full compliance with the study',
#  'unrelated to the malignancy',
#  'esophagus',
#  'invasive',
#  'uncontrolled',
#  'unresolved',
#  'E. coli derived',
#  'cytologically proven',
#  'histologically proven',
#  'Unresectable',
#  'locally advanced',
#  'esophagus',
#  'Initial',
#  'study-specific',
#  'adequate',
#  'Meet DSM-IV criteria',
#  'DSM-IV',
#  'primary',
#  'Comorbid',
#  'additional',
#  'primary',
#  'DSM- IV',
#  'concurrent',
#  'Stable',
#  'uncontrolled',
#  'active',
#  'active',
#  'active',
#  'interfere with consent',
#  'interfere with follow-up',
#  'severe',
#  'Unresectable',
#  'disease limited to liver',
#  'measurable disease',
#  'measurable disease',
#  'outside the radiation field',
#  'responsive to diuretics',
#  '20 cc',
#  'lasting longer than 30 minutes',
#  'totally occluded major epicardial vessel',
#  'stable',
#  'unstable',
#  'located in different vessels',
#  'located in different territories',
#  'in another major epicardial coronary artery',
#  'de novo',
#  'Ventavis Summary of Product Characteristics and patient package insert',
#  'for primary pulmonary hypertension',
#  'reviewed by transplant center',
#  'reviewed by transplant center',
#  'for transplantation',
#  'stable',
#  'uncontrolled by medication',
#  'Uncontrolled',
#  'requiring',
#  'controlled with medication',
#  'disease free',
#  'in remission',
#  'adequately treated',
#  'injectable',
#  'oral',
#  'Measurable',
#  'site other than bone-only',
#  'Primary tumor',
#  'borderline',
#  'Measurable',
#  'amenable to curative treatment',
#  'Measurable',
#  'persistent',
#  'recurrent',
#  'amenable to curative treatment',
#  'persistent',
#  'recurrent',
#  'low malignant potential',
#  'Ovarian',
#  'endometrial',
#  'cervical',
#  'stable dose',
#  'evaluable disease',
#  'curatively',
#  'uncontrolled',
#  'unresectable',
#  'uni-dimensionally measurable',
#  'not foreseen by the study protocol',
#  'first dose can be given',
#  'exacerbated',
#  'uncomplicated',
#  'obvious',
#  'parent',
#  'guardian',
#  'Pre-existing',
#  'successful',
#  'significant',
#  'clinically significant',
#  'clinically relevant',
#  'Axis 1',
#  'affect CNS',
#  'Methadone-maintained',
#  'foreseen by the study protocol',
#  'Chronic',
#  'confirmed',
#  'suspected',
#  'which prevents the subject from participation in the study',
#  'investigational',
#  'non-registered',
#  'other than the study vaccine(s)',
#  'Serious',
#  'well controlled',
#  'requiring therapy',
#  'any other',
#  'failed',
#  'severe',
#  'doubt',
#  'testing zone',
#  'lower back',
#  'clinically significant',
#  'chronic',
#  'recurrent',
#  'active',
#  'Local',
#  'systemic',
#  'interacts with the outcome measures',
#  'MDRD formula',
#  'potentially life threatening',
#  'symptomatic',
#  'Uncontrolled',
#  'alter the absorption, distribution, metabolism, or excretion of study drugs',
#  'that would jeopardize the evaluation of efficacy',
#  'that would jeopardize safety',
#  'other',
#  'prohibited by the protocol',
#  'place the patient at higher risk from his/her participation in the study',
#  'Other',
#  'protocol-defined',
#  'Modification of Diet in Renal Disease (MDRD) formula',
#  'stable',
#  'Newly diagnosed',
#  'stable',
#  'grass',
#  'ragweed pollen',
#  'not amenable',
#  'severe',
#  'Moderate',
#  'increased dosage',
#  'significant',
#  'severely',
#  'severe',
#  'moderate',
#  'increasing dosage',
#  'stable',
#  'Major',
#  'significant',
#  'major',
#  'Other',
#  'active',
#  'Uncontrolled',
#  'active',
#  'Clinically significant',
#  'symptomatic',
#  'serious',
#  'major',
#  'other',
#  'significant',
#  'severe',
#  'Uncontrolled serious',
#  'definitive',
#  'biochemically',
#  'radiographically evident',
#  'Non-castrate',
#  'metastatic',
#  'histologically confirmed',
#  'alkylating agent-based',
#  'carboplating-based',
#  'metastatic',
#  'poorly-controlled',
#  'failure',
#  'stable doses',
#  'Clinical diagnosis',
#  'serious',
#  'uncontrolled',
#  'Serious',
#  'significant',
#  'inhaled',
#  'systemic',
#  'high dose',
#  'clinically significant',
#  'low probability(by surgeon estimate) of conversion to open procedure',
#  'significant',
#  'affect the drug absorption',
#  'acceptable form',
#  'amphetamine',
#  'barbiturates',
#  'benzodiazepine',
#  'cannabinoid',
#  'cocaine',
#  'opiates',
#  'phencyclidine',
#  'methadone',
#  'Predominant',
#  'determined by the investigator',
#  'neo-adjuvant setting',
#  'adjuvant setting',
#  'Grade ≥ 3',
#  'appropriately treated',
#  'other',
#  'metastatic',
#  'locally advanced',
#  'unresectable',
#  'untreated',
#  'symptomatic',
#  'require therapy',
#  'symptomatic',
#  'requiring treatment',
#  'symptomatic',
#  'adjuvant',
#  'Severe',
#  'requiring current continuous oxygen therapy',
#  'severe',
#  'uncontrolled',
#  'clinically significant',
#  'Major',
#  'significant',
#  'cytologically confirmed',
#  'Histologically confirmed',
#  'highly effective',
#  'non-hormonal',
#  'serious',
#  'potent',
#  'other types',
#  'connective tissue disease associated',
#  'congenital heart disease',
#  'uncontrolled',
#  'evoluting',
#  'severe',
#  'severe',
#  'severe',
#  'evoluting',
#  'requiring antibiotherapy',
#  'do not allow the protocol follow-up',
#  'HLA-A2',
#  'surgically resectable',
#  'measurable',
#  'WHO criteria',
#  'Q wave positive',
#  'enzyme positive',
#  'surgical',
#  'percutaneous',
#  'precludes surgery',
#  'Clinically significant',
#  'Clinically significant',
#  'exercise-related',
#  'expected to compromise survival',
#  '3 minutes of unloaded peddling on cycle ergometer',
#  'interferes with completion of initial or follow-up assessments',
#  'on room air',
#  'rehabilitation',
#  'rehabilitation',
#  'refractory to treatment',
#  'steroids dependant',
#  'in relapse',
#  'refractory to treatment',
#  'in relapse',
#  'steroids dependant',
#  'significant',
#  'clinically significant',
#  'effective',
#  'clinically relevant',
#  'significant',
#  'effective',
#  'Endoscopically confirmed',
#  'Endoscopically confirmed',
#  'aspirin-induced',
#  'affecting gastric acid secretion',
#  'Clinically significant',
#  'Serious',
#  'Severely',
#  'adequate',
#  'inadequately controlled',
#  'Significant',
#  'Clinically significant',
#  'Clinically significant',
#  'other',
#  'severe',
#  'other',
#  'Cytologically proven',
#  'previously unrecognized',
#  'peripheral blood',
#  'PB',
#  'Initial',
#  'bone marrow',
#  'PB',
#  'extensively spread',
#  'extensive',
#  'non-emergency',
#  'excessive',
#  'to the breast',
#  'of the breast',
#  'associated with their pain diagnosis',
#  'could not be discontinued',
#  'idiopathic',
#  'painful',
#  'distal',
#  'symmetric',
#  'painful',
#  'average',
#  'last',
#  'Untreated',
#  'undiagnosed',
#  'significant',
#  'undiagnosed',
#  'Unexplained',
#  'abnormal',
#  'severe',
#  'progressive',
#  'serious',
#  'self-reported',
#  'normal',
#  'Uncontrollable',
#  'when upright',
#  'incomplete',
#  'after OGTT',
#  'significant',
#  'mild',
#  'moderate',
#  'emergency',
#  'basal',
#  'Uncontrolled',
#  'Severe',
#  'large',
#  'Medium',
#  'Coexisting',
#  'Severe',
#  'active',
#  'severe',
#  'Severe',
#  'Severe',
#  'status unknown',
#  'in relapse',
#  'refractory',
#  'non-hematological',
#  'clinically significant',
#  'Grade >1 by NCI CTCAE v4',
#  'clinically significant',
#  '>Grade 1',
#  'non hematological',
#  'persistent',
#  'that prolong QT/QTc interval',
#  'Uncontrolled',
#  'significant',
#  'uncontrolled',
#  'nonmelanotic',
#  'Stage 1 cervix',
#  'Morphologically documented',
#  'primary',
#  'non-hematological',
#  'clinically significant',
#  '≤Grade 1',
#  'from prior treatment',
#  'any other',
#  'primary',
#  'DSM-IV',
#  'other',
#  'other',
#  'DSM-IV',
#  'Axis II Cluster A',
#  'significant',
#  'childhood',
#  'stabilized',
#  'oral',
#  'primary',
#  'DSM-IV',
#  'DSM-IV',
#  'comorbid',
#  'baseline',
#  'medically acceptable',
#  'chronic',
#  'adequately',
#  'unresolved',
#  'compromise study participation',
#  'fetal',
#  'Clinically significant',
#  'averaged over the previous 3 years',
#  'chronic',
#  'adequate',
#  'unstable',
#  'controlled',
#  'chronic',
#  'severe',
#  'chronic',
#  'chronic',
#  'significant',
#  'other',
#  'ocular',
#  'systemic',
#  'age-related',
#  'Genotype 1',
#  'predisposing to brain herniation or bleeding diathesis',
#  'opportunistic',
#  'silent',
#  'documented',
#  'De novo lesion',
#  'in proximal coronary artery',
#  'mid epicardial coronary artery',
#  'Angiographically defined',
#  'treated',
#  'invasive',
#  'treated definitively',
#  'other than the entry diagnosis',
#  'uncontrolled',
#  'unstable',
#  'Symptomatic',
#  'rate-controlled',
#  'stable',
#  'treated',
#  '> Grade 2',
#  'serious',
#  'serious',
#  'major',
#  'significant',
#  'Uncontrolled',
#  'in the opinion of the investigator may increase the risks',
#  'stage IV',
#  'disseminated',
#  'malignant',
#  'predominant histology',
#  'small cell anaplastic elements',
#  'locally advanced',
#  'locally advanced',
#  'symptomatic',
#  'Cockcroft-Gault method',
#  'other',
#  'underlying',
#  'brain',
#  'fetal',
#  'infarct related artery',
#  'non-infarct related artery',
#  'Unprotected',
#  'unsuitable for proper',
#  'heavy',
#  'located in a saphenous vein graft',
#  'within the native vessel',
#  'accessed through the graft',
#  'single- vessel',
#  'multi-vessel',
#  'de novo',
#  'restenotic',
#  'in-stent',
#  'restenotic',
#  'emergency',
#  'urgent',
#  'elective',
#  'stable',
#  'unstable',
#  'silent',
#  'de novo',
#  'restenotic',
#  'in-stent restenotic',
#  'in an infarct -related artery',
#  'non-infarct-related artery',
#  'due to pulmonary complications',
#  'unstable',
#  'severe',
#  'severe',
#  'subclavian',
#  'distal',
#  'non-functional',
#  'in the internal jugular vein position',
#  'in the subclavian vein position',
#  'Clinically significant',
#  'severity of the agitation',
#  'Clinically significant',
#  'severity of the delusions',
#  'Clinically significant',
#  'severity of the hallucinations',
#  'stable',
#  'Uncontrolled',
#  'as verified by compartment pressure of the rectus sheath (CPRS)',
#  'Symptomatic',
#  'significant',
#  'as determined by the study physician',
#  'Significant',
#  'advanced',
#  'symptomatic',
#  'serious',
#  'serious',
#  'related to heart problems',
#  'abnormal',
#  'stable doses',
#  'significant',
#  'prohibited',
#  'licensed',
#  'licensed',
#  'with spermicide',
#  'chronic',
#  'of more than 450ml',
#  'secondary',
#  'Primary',
#  'Severe',
#  'in remission',
#  'Group A',
#  'Group B',
#  'with active disease',
#  'CMV-positive',
#  'on room air',
#  'significant',
#  'severe',
#  'congenital',
#  'severe',
#  'non-sustained',
#  'polymorphic',
#  'with endocrine activity',
#  'relatively stable',
#  'post-bronchodilator',
#  'Clinically significant',
#  'secondary to AAT deficiency',
#  'adequate',
#  'deemed reliable by the investigator',
#  'life threatening',
#  'human plasma derived',
#  'post bronchodilator',
#  'post-bronchodilator',
#  'moderate',
#  'severe',
#  'required change in treatment',
#  'systemic',
#  'significant',
#  'stable',
#  'deemed reliable by the investigator',
#  'systemic',
#  'bacterial etiology',
#  'viral etiology',
#  'fungal etiology',
#  'caused by Chlamydia',
#  'caused by Mycobacterium',
#  'caused by Acanthamoeba',
#  'topical',
#  'systemic',
#  'components of the formulations',
#  'Lasik method',
#  'Lown classes 4',
#  'Lown classes 5',
#  'significant',
#  'bilateral',
#  'unilateral',
#  'Planned',
#  'stage 5',
#  'Metastatic',
#  'estrogen positive',
#  'moderate',
#  'mild',
#  'Uncontrolled',
#  'moderate',
#  'severe',
#  'severe',
#  'peritoneal',
#  'severe',
#  'Systemic',
#  'Oral',
#  'parenteral',
#  'intra-articular',
#  'oral',
#  'systemic',
#  'post-albuterol/salbutamol',
#  'post-albuterol/salbutamol',
#  'using NHANES III reference equations',
#  'Post-bronchodilator',
#  'self-administered',
#  'with a valved-holding chamber',
#  'significant',
#  'severe',
#  'chronic moderate',
#  'could disturb the study assessment and evaluation of the skin',
#  'that cause immunosuppression',
#  'clinically significant',
#  'Clinically significant',
#  'severe',
#  'moderate',
#  'clinically significant',
#  'ascertained by medical history, physical examination and laboratory determinations',
#  'significant',
#  'substantial',
#  'clinically significant',
#  'clinically significant',
#  'sliding',
#  'at gastro-esophageal junction',
#  'Rome III criteria',
#  'inadequate relief',
#  'prostate',
#  'adjacent organs',
#  'seminal vesicles',
#  'pelvic',
#  'Severe',
#  'decompensated',
#  'Pre-existent',
#  'hepatitis C virus',
#  'hepatitis D virus',
#  'human immunodeficiency virus',
#  'HIV',
#  'inherited',
#  'acquired',
#  'significant',
#  'significant',
#  'chronic',
#  'alcohol',
#  'I.V. drugs',
#  'inhaled drugs',
#  'Compensated',
#  'skin',
#  'blood',
#  'muscle tissue',
#  'administrative reasons',
#  'severe',
#  'mild',
#  'Severe',
#  '20-30 minutes',
#  'amount of time to complete the MRI procedure',
#  'MRI compatible',
#  'meeting criteria for the diagnosis of diabetes mellitus according to the American Diabetes Association',
#  'Systemic',
#  'inhaled',
#  'stable',
#  'decompensated',
#  'Uncontrolled',
#  'other variety',
#  'serious',
#  'blast crisis',
#  'de novo',
#  'moderate-to-severe',
#  'segmental',
#  'generalized',
#  'primary',
#  'optimal',
#  'severe',
#  'stable dose',
#  'extra-renal organ',
#  'cauda equina',
#  'conus',
#  'Unstable',
#  'finger',
#  'thumb',
#  'upper extremity',
#  'Stable',
#  'Medically',
#  'thumb',
#  'finger',
#  'histologically proven',
#  'multiple tracts',
#  'rectoanal region',
#  'tandospirone',
#  'unstable',
#  'Serious',
#  'clinically significant',
#  'living donor',
#  'deceased donor',
#  'Expanded Criteria Donors (ECD)',
#  'Locally unresectable',
#  'Metastatic',
#  'Severe',
#  'Primary',
#  'untreated',
#  'Questionnaire for Verifying Stroke-Free Status (QVSFS)',
#  'Acute',
#  'Framingham criteria',
#  'with measurable disease',
#  'can be accurately measured in at least one dimension',
#  'untreated',
#  'locally advanced',
#  'metastatic',
#  'with EGFR activating mutation',
#  'well-differentiated',
#  'primary',
#  'in extremities',
#  'staging IIB',
#  'Severe',
#  'severe',
#  'symptomatic',
#  'interfere with subject participation',
#  'other',
#  'Axis II',
#  'DSM-IV-TR',
#  'significant',
#  'serious',
#  'first-line',
#  'standard',
#  'monotherapy',
#  'even if receiving erythropoietin',
#  'even if receiving G-CSF',
#  'criteria per Brazilian Ministry of Health',
#  'with activity against S. aureus',
#  'parenteral',
#  'parenteral',
#  'with activity against MRSA',
#  'S. aureus',
#  'left-sided',
#  'nonhardware-associated',
#  'diagnostic-only',
#  'Active',
#  'clinically significant',
#  'clinically significant',
#  'would prohibit the consumption of standardized meals',
#  'treated',
#  'isolated',
#  'on- or off-pump or repeat',
#  "redo's",
#  'DSM-IV',
#  'High',
#  'Axis I',
#  'DSM-IV',
#  'Acute',
#  'severe',
#  'decompensated',
#  'Neurological',
#  'current',
#  'Corrected',
#  'unipolar',
#  'Novartis sponsored',
#  'have the potential to prolong the QT interval',
#  'inducing Torsade de Pointes',
#  'highly effective methods',
#  'Novartis-sponsored',
#  'stable',
#  'any vessel',
#  'of the target vessel(s)',
#  'severe',
#  'active',
#  'active',
#  'acquired',
#  'congenital',
#  'new',
#  'therapeutically effective',
#  'preclude effective catheter placement',
#  'may not be safely held for the procedure',
#  'suitable for radiation therapy',
#  'to the region proposed for HDR brachytherapy treatment',
#  'rituximab-based',
#  'high-risk',
#  'cT3',
#  'intermediate-risk',
#  'confirmed',
#  'other',
#  'other',
#  'at least 2cm from the hilum',
#  'per pancreatobiliary surgeon',
#  'intramuscular',
#  'intravenous',
#  'investigational',
#  'latent',
#  'age-appropriate',
#  '1987 revised American College of Rheumatology criteria',
#  'first time',
#  'first year',
#  'Moderate',
#  'severe',
#  'significant',
#  'by a neurologist',
#  'anti-epileptic activity',
#  'without rupture',
#  'with rupture',
#  'Treating surgeon',
#  'class I',
#  'class III',
#  'left',
#  'symptomatic',
#  'significant',
#  'significant',
#  'abnormal',
#  'arrhythmogenic',
#  'untreated',
#  'uncontrolled',
#  'active',
#  'symptomatic',
#  'symptomatic',
#  'normal',
#  'structural',
#  '12 channel surface ECG',
#  'valvular',
#  'congenital',
#  'Poorly controlled',
#  'Poorly controlled',
#  'Severe',
#  'resting',
#  'Awake',
#  'change',
#  'severe',
#  'Moderate',
#  'elective',
#  'under general anesthesia',
#  'investigational',
#  'would interfere with adherence to study requirements',
#  'Serious',
#  'would interfere with the ability to adhere to study requirements',
#  'estrogen derivatives',
#  'estrogen',
#  "Hartmann's pouch",
#  'Clinical diagnosis',
#  'severe',
#  'in the opinion of the Investigator, would affect subject safety or compliance',
#  'severe',
#  'mild',
#  'estrogen-containing',
#  'Severe',
#  'severity',
#  'Uncontrolled',
#  'stage IIIB/IV',
#  'measurable',
#  'standard',
#  'severe',
#  'for which the doctor of the patients do not agree his or her participating',
#  'bladder',
#  'planned',
#  'Active',
#  'major',
#  'ophthalmologic',
#  'spinal',
#  'Brain',
#  'Active',
#  'elective',
#  'at least one component',
#  'untreated',
#  'may significantly alter the absorption of dovitinib',
#  'clinically significant',
#  'Stage 4',
#  'stable',
#  'locally advanced',
#  'used in the trial',
#  'involuntarily',
#  'Moderate',
#  'severe',
#  'injectable',
#  'oral',
#  'sufficient severity',
#  'sufficient severity',
#  'Resistant',
#  'despite the use of three or more anti-hypertensive drugs',
#  'Severe',
#  'clinically significant',
#  'New York Heart Association Class III or IV',
#  'Significant',
#  'Severe',
#  'significant',
#  'that would prevent participation in exercise',
#  'untreated',
#  'treated',
#  'Clinically significant',
#  'treated',
#  'stable',
#  'uncontrolled',
#  'severe',
#  'clinically significant',
#  'significant',
#  'resistance to standard therapies',
#  'for which no standard therapies exist',
#  'accurately assessed at baseline',
#  'suitable for repeated assessment',
#  'severe',
#  'ROME III criteria',
#  'mixed form',
#  'active',
#  'refractory',
#  'relapsed',
#  'moderate to severe',
#  '0-10 scale',
#  'site of the defect',
#  'Severe',
#  'not stable',
#  'uncontrolled',
#  'uncontrolled',
#  'acute phase',
#  'severe',
#  'moderately severe',
#  'fibrin-specific',
#  'non-fibrin-specific',
#  'cannot be safely discontinued',
#  'severe',
#  'moderate',
#  'acute',
#  'is associated with a life expectancy < 1 year',
#  'severe',
#  'severe',
#  'Extraliver',
#  'Histologically confirmed',
#  'other',
#  'Adequate',
#  'AF',
#  'Significant',
#  'Uncontrolled',
#  'NYHA Class III',
#  'NYHA Class IV',
#  'Successful',
#  'Maxilla',
#  'mandible',
#  'clinically significant',
#  'active',
#  'clinically significant',
#  'poorly controlled',
#  'poorly controlled',
#  'symptomatic',
#  'Stable',
#  'Rotterdam criteria 2004',
#  'scheduled to last at least 2 hours',
#  'PCR-',
#  'HBsAg-',
#  'requiring systemic treatment',
#  'Significant',
#  'major',
#  'Major',
#  'requiring treatment',
#  'Treated',
#  'stable doses',
#  'untreated',
#  'DSM-IV-TR',
#  'DSM-IV-TR',
#  'Invasive',
#  'extending into the porta',
#  'left branch',
#  'right branch',
#  'could prevent patient from receiving treatment',
#  'metastatic',
#  'advanced',
#  'intermediate',
#  'Early',
#  'investigational',
#  'non-registered',
#  'licensed',
#  'other investigational',
#  'significant',
#  "could interfere with the subject's participation in the study",
#  'Clinically significant',
#  'affects the immune system',
#  'known to be frequently associated with significant major organ toxicity',
#  'oral',
#  'injectable',
#  'severe',
#  'below 12cm from anal verge',
#  'Other',
#  'Significant',
#  'above to 12 cm from the anal verge',
#  'unresectable',
#  'synchronous',
#  'uncontrolled',
#  'symptomatic',
#  'significant',
#  'major',
#  'related to the NK cell line',
#  'Other',
#  'other',
#  'impact on immune system functioning',
#  'comorbid',
#  'DSM-IV',
#  'severe',
#  'inadequate',
#  'adequate',
#  'with phacoemulsification',
#  'implantation of a posterior chamber intraocular lens',
#  'both eyes',
#  '1987 American College of Rheumatology (ACR) criteria',
#  'subcutaneous',
#  'homolateral',
#  'habitual',
#  'immediate',
#  'serious',
#  'as judged by the Investigator',
#  'Clinically significant',
#  'abnormal',
#  'symptomatic',
#  'stage IV',
#  'stage V',
#  'Nephrotic range',
#  'Severe',
#  'greater than 1st degree',
#  'Decompensated',
#  'World Health Organization Group 2',
#  'unilateral',
#  'bilateral',
#  'for laparoscopic repair',
#  'nerve radial',
#  'nerve ulnar',
#  'median nerve',
#  'interfering with blood coagulation',
#  'Nuss procedure',
#  'suitable for chemotherapy',
#  'severe',
#  ...]

# %%
df_ents[df_ents.Char_spans.apply(len) > 2]
# Out:
#                     Id Entity_id  \
# 19     NCT00050349_exc       T23
# 27     NCT00050349_exc       T31
# 43     NCT00050349_exc       T53
# 47     NCT00050349_exc       T57
# 77     NCT00050349_inc       T19
# ...                ...       ...
# 44507  NCT03648021_inc       T22
# 44537  NCT03663387_exc       T28
# 44558  NCT03663387_exc       T52
# 44559  NCT03663387_exc       T53
# 44580  NCT03663387_exc       T76
#
#                                               Mention     Category  \
# 19                                     greater than 1        Value
# 27                                  in-dwelling ports       Device
# 43                                    medical illness    Condition
# 47       inability to return for all scheduled visits         Mood
# 77                 major impairment of renal function    Condition
# ...                                               ...          ...
# 44507                           intracranial pressure  Measurement
# 44537                    limiting validity of imaging    Qualifier
# 44558   over the counter memory enhancing medications         Drug
# 44559  over the counter memory protecting medications         Drug
# 44580                 likely to affect brain function    Qualifier
#
#        Start_char  End_char                Char_spans
# 19            751       771      (751, 763, 770, 771)
# 27            955       981      (955, 966, 976, 981)
# 43           1311      1341  (1311, 1318, 1334, 1341)
# 47           1443      1504  (1443, 1452, 1470, 1504)
# 77            331       376      (331, 356, 368, 376)
# ...           ...       ...                       ...
# 44507         317       354      (317, 329, 346, 354)
# 44537         367       423      (367, 387, 416, 423)
# 44558         792       851      (792, 825, 840, 851)
# 44559         792       851      (792, 815, 829, 851)
# 44580        1309      1353  (1309, 1331, 1345, 1353)
#
# [1796 rows x 7 columns]

# %%
# A sanity check:
check = []
for _id, text in df_texts.values.tolist():
    df_tmp = df_ents[df_ents.Id == _id]
    check_tmp = df_tmp.apply(
        func = lambda r: [_id, r.Mention, text[r.Start_char: r.End_char], r.Char_spans],
        axis = 1,
    ).values.tolist()
    check += check_tmp
    
df_check = pd.DataFrame(check, columns = ['Id', 'Mention', 'Span', 'Char_spans'])

# %%
# Mention and Span are the same for *almost* all entities:
print(df_check[df_check.Mention != df_check.Span].shape)
print(df_check[(df_check.Mention != df_check.Span) & (df_check.Char_spans.apply(len) == 2)].shape)

df_check[(df_check.Mention != df_check.Span) & (df_check.Char_spans.apply(len) == 2)]
# Out:
# (1981, 4)
# (194, 4)
#                     Id                                            Mention  \
# 6361   NCT01352598_inc                                    prostate cancer
# 10279  NCT01980680_exc                                   OHSS development
# 17492  NCT02425774_exc                               chronic pancreatitis
# 21757  NCT02590822_inc  Capacity to provide informed consent before an...
# 23477  NCT02654912_exc                                    first trimester
# ...                ...                                                ...
# 39885  NCT03338296_exc                                           the same
# 39886  NCT03338296_exc  (Note: All female participants will be conside...
# 40879  NCT03366779_exc  Subject is currently involved in another inves...
# 41349  NCT03387059_exc  Known hypersensitivity to any of the component...
# 42047  NCT03460002_inc                           Person Surveillance Site
#
#                                                     Span    Char_spans
# 6361                                    prostate cancer     (383, 399)
# 10279                                  OHSS development       (75, 92)
# 17492                              chronic pancreatitis     (149, 170)
# 21757  Capacity to provide informed consent before an...      (0, 110)
# 23477                                   first trimester     (398, 414)
# ...                                                  ...           ...
# 39885                                           he same   (6883, 6891)
# 39886  Note: All female participants will be consider...  (7075, 7328)
# 40879  Subject is currently involved in another inves...  (3001, 3065)
# 41349  Known hypersensitivity to any of the component...    (820, 884)
# 42047                      Demographic Surveillance Site    (104, 133)
#
# [194 rows x 4 columns]

# %% [markdown]
# ## 2.2 Get flattened non-overlapping entities
#
# [Table of content](#TOC)

# %%
categories = [
    # domain
    'Condition',                     # - in C2Q
    'Device',                        # present in OMOP CDM, can be precise ('Pacemaker') or broad ('barrier method of birth control)
    'Drug',                          # - in C2Q
    'Measurement',                   # - in C2Q
    'Person',                        # Demographic (sex, age), but also contains mislabeled Condition ('Premenopausal', drug users'), mislabeled Measurement ('body mass index') and irrelevant terms ('Incarcerated')
    'Procedure',                     # - in C2Q
    'Visit',                         # codable ?
    
    # field
    'Value',                         # - in C2Q
    'Temporal',                      # - in C2Q
    'Qualifier',                     # Originaly a Construct entity. Modifier terms similar to Observation
    'Observation',                   # - in C2Q # greatly overlaps Qualifier, and the delta seems useless
    # 'Reference_point',             # reference point in time, absolute ("3 times the agent's half-life") or relative ('initiation of treatment')
    # 'Mood',                        # useless

    # construct
    # 'Negation',                    # negation expressed as a NER + RelEx problem to be complete
    # 'Multiplier',                  # CAUTION here, as it covers Value ('> 500 mg/m^2') associated with Drug, and and Logical label ('3 or more')
]

# %%
df_ents = get_ner_entities(df_texts, df_ents, categories)

# %%
df_ents.head()
# Out:
#                 Id                     Mention  Start_char  End_char  \
# 0  NCT00050349_exc                 symptomatic          14        25
# 1  NCT00050349_exc              CNS metastases          26        40
# 2  NCT00050349_exc  leptomeningeal involvement          44        70
# 3  NCT00050349_exc            brain metastases          92       108
# 4  NCT00050349_exc                     treated         144       151
#
#   Entity_id   Category
# 0    (T65,)  Qualifier
# 1     (T1,)  Condition
# 2     (T2,)  Condition
# 3     (T4,)  Condition
# 4     (T5,)  Procedure

# %%
df_ents.Category.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df_ents.to_csv(os.path.join(path_to_data, final_dataset_name, 'chia_ents.tsv'), sep = "\t", index = False)

# %% [markdown]
# <a id="bio"></a>

# %% [markdown]
# ## 2.3 Convert entities to BIO format
#
# [Table of content](#TOC)

# %%
df_spans = convert_to_bio(df_texts, df_ents)
df_spans.shape
# Out:
# (76064, 4)

# %%
df_spans.head()
# Out:
#                 Id        Sequence_id         Mention   Category
# 0  NCT00050349_exc  NCT00050349_exc_0  Patients with           O
# 1  NCT00050349_exc  NCT00050349_exc_0     symptomatic  Qualifier
# 2  NCT00050349_exc  NCT00050349_exc_0                          O
# 3  NCT00050349_exc  NCT00050349_exc_0  CNS metastases  Condition
# 4  NCT00050349_exc  NCT00050349_exc_0             or           O

# %%
df_spans.to_csv(os.path.join(path_to_data, final_dataset_name, 'chia_spans.tsv'), sep = "\t", index = False)

# %%
tokenizer = English()
df_bio = convert_to_bio(df_texts, df_ents, tokenizer = lambda s: [t.text for t in tokenizer(s)])

df_bio.shape
# Out:
# (205290, 4)

# %%
df_bio.head(10)
# Out:
#                 Id        Sequence_id         Mention     Category
# 0  NCT00050349_exc  NCT00050349_exc_0        Patients            O
# 1  NCT00050349_exc  NCT00050349_exc_0            with            O
# 2  NCT00050349_exc  NCT00050349_exc_0     symptomatic  B-Qualifier
# 3  NCT00050349_exc  NCT00050349_exc_0                            O
# 4  NCT00050349_exc  NCT00050349_exc_0             CNS  B-Condition
# 5  NCT00050349_exc  NCT00050349_exc_0      metastases  I-Condition
# 6  NCT00050349_exc  NCT00050349_exc_0                            O
# 7  NCT00050349_exc  NCT00050349_exc_0              or            O
# 8  NCT00050349_exc  NCT00050349_exc_0  leptomeningeal  B-Condition
# 9  NCT00050349_exc  NCT00050349_exc_0     involvement  I-Condition

# %%
df_bio.to_csv(os.path.join(path_to_data, final_dataset_name, 'chia_bio.tsv'), sep = "\t", index = False)

# %% [markdown]
# <a id="prompt"></a>

# %% [markdown]
# ## 2.3 Convert entities to LLM prompt format
#
# [Table of content](#TOC)

# %%
prompts = convert_to_prompts(df_texts, df_ents, bos_term = '', sep_term = '\n\n###\n\n', end_term = '\n\nEND')

# %%
prompts[:2]
# Out:
# [{'id': 'NCT00050349_exc_0',
#   'prompt': 'Patients with symptomatic CNS metastases or leptomeningeal involvement \n\n###\n\n',
#   'completion': 'symptomatic\nQualifier\n\nCNS metastases\nCondition\n\nleptomeningeal involvement\nCondition\n\nEND'},
#  {'id': 'NCT00050349_exc_1',
#   'prompt': 'Patients with known brain metastases, unless these metastases have been treated and/or have been stable for at least six months prior to study start. Subjects with a history of brain metastases must have a head CT with contrast to document either response or progression. \n\n###\n\n',
#   'completion': 'brain metastases\nCondition\n\ntreated\nProcedure\n\nbeen stable for\nQualifier\n\nat least six months prior to study start\nTemporal\n\nhistory of\nTemporal\n\nbrain metastases\nCondition\n\nhead CT with contrast\nProcedure\n\nEND'}]

# %%
dicts_to_jsonl(
    data_list = prompts, 
    filename = os.path.join(path_to_data, final_dataset_name, 'chia_prompts.jsonl.gz'), 
    compress = True,
)

# %% [markdown]
# [Table of content](#TOC)
